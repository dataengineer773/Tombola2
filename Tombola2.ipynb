# %%
import abc

# %%
class Tombola(abc.ABC):
    def load(self, iterable):
        """Add items from an iterable"""
    def pick(self):
        """Remove item at random, returning it,This method should raise'LookError'when the istance is empty"""
        return bool(self.inspect())
